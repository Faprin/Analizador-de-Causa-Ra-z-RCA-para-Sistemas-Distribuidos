# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importacion de Datos recuperados de LOKI

# %%
df_1 = pd.read_csv("../datasets/01_logs_dataset.csv")
df_2 = pd.read_csv("../datasets/02_logs_dataset.csv")
df = pd.concat([df_1, df_2], ignore_index=True)
df.head()
# Out:
#                  @timestamp            service level    event_type  outcome  \
# 0  2026-07-03T08:03:23.032Z  api-autenticacion  INFO  HTTP_REQUEST  SUCCESS
# 1  2026-07-03T08:04:56.876Z  api-autenticacion  INFO  HTTP_REQUEST  SUCCESS
# 2  2026-07-03T08:04:59.767Z  api-autenticacion  INFO  HTTP_REQUEST  SUCCESS
# 3  2026-07-03T08:05:04.616Z  api-autenticacion  INFO  HTTP_REQUEST  SUCCESS
# 4  2026-07-03T08:05:06.940Z  api-autenticacion  INFO  HTTP_REQUEST  SUCCESS
#
#   http_method            http_uri  http_status  duration_ms error_type  \
# 0        POST  /api/auth/register        201.0        363.0        NaN
# 1        POST     /api/auth/login        200.0        115.0        NaN
# 2        POST     /api/auth/login        200.0        108.0        NaN
# 3        POST     /api/auth/login        200.0        107.0        NaN
# 4        POST     /api/auth/login        200.0         87.0        NaN
#
#   error_message error_origin                           traceId
# 0           NaN          NaN  6a476cca227cf2c2a7778eea6814c767
# 1           NaN          NaN  6a476d28bef605f56445e5f31a75ab8a
# 2           NaN          NaN  6a476d2b308ea5cc0f8932e9de3ca02d
# 3           NaN          NaN  6a476d30b15c719121fc2c7488b11b02
# 4           NaN          NaN  6a476d323360f89f718e7343d5f6686b

# %%
print("=========== INFORMACION DE LOS DATOS ===========")
print(f"Total de registros: {len(df)}")
print(f"\nColumnas disponibles:\n{df.columns.tolist()}")
print(f"\nDistribución de event_type:\n{df['event_type'].value_counts()}")
print(f"\nDistribución de level:\n{df['level'].value_counts()}")
print(f"\nDistribución de service:\n{df['service'].value_counts()}")
print(f"\nValores nulos por columna:\n{df.isnull().sum()}")
# Out:
# =========== INFORMACION DE LOS DATOS ===========
# Total de registros: 9940
#
# Columnas disponibles:
# ['@timestamp', 'service', 'level', 'event_type', 'outcome', 'http_method', 'http_uri', 'http_status', 'duration_ms', 'error_type', 'error_message', 'error_origin', 'traceId']
#
# Distribución de event_type:
# event_type
# UNHANDLED_ERROR    2279
# HTTP_REQUEST       2177
# SERVER_ERROR       1968
# Name: count, dtype: int64
#
# Distribución de level:
# level
# ERROR    4884
# WARN     2705
# INFO     2351
# Name: count, dtype: int64
#
# Distribución de service:
# service
# api-inventario       6003
# api-pedidos          3833
# api-autenticacion     104
# Name: count, dtype: int64
#
# Valores nulos por columna:
# @timestamp          0
# service             0
# level               0
# event_type       3516
# outcome          5795
# http_method      5795
# http_uri         5795
# http_status      5795
# duration_ms      5795
# error_type       7661
# error_message    8091
# error_origin     8880
# traceId           194
# dtype: int64

# %% [markdown]
# ## Documentacion sobre los datos
# - *event_type, service, http_metos*: Son datos ordinales. Nos indican el tipo de peticion. Usarmeos OnehotEncoder
# - *duration_ms, http_status*: Valores numericos que se pueden utilizar de entrada. Podria usarse StandardScaler para mejorar la precision final
# - *@timestamp*: De tipo temporal. Requiere de un procesamiento donde vamos a sacar varias columnas: hour_of_day, day_of_week, minute_of_hour
# - *level*: es de categoria ordinal, es decir, Warn, Info y Error, tendrán pesos diferentes e indicaran diferentes grados, en este caso, de gravedad. Por lo tanto se mapearan a 0, 1, 2 para que el modelo comprenda que contienen diferentes importancias
# - *error_message, error_origin*: Serán tratados por un NLP en un futuro. Por ahora trataremos error_message como un valor de 0, si existe o 1, sino existe
# - *outcome*: Aporta redundancia al dataset, ya tenemos http_status para que el modelo pueda detectar si la operacion ha salido correctaamente o de manera fallida. Se elimina
# - *traceId*: Cambiante para cada transaccion, el modelo tenderia a memorizar. Esta variable se eleminar porque confundiria al modelo

# %% [markdown]
# # Transformacion de los datos

# %%
def nulos(df):
    nulos = df.isna().sum()
    columnas_nulas = nulos[nulos>0]
    print(columnas_nulas.sort_values(ascending=False))

# %%
# Elimina filas donde event_type, http_uri y duration_ms son todos nulos Y quitamos outcome porque aporta redundancia
df = df.dropna(subset=["event_type", "http_uri", "duration_ms"], how="all")
df = df.drop(columns=["outcome"])

# Elimina también los endpoints de caos
df = df[~df["http_uri"].str.contains("/chaos/", na=False)]

# %%
# Rellenamos nulos a UKNOWN
df["http_uri"] = df["http_uri"].fillna("UNKNOWN")

# %%
def uri_a_servicio_destino(uri):
    if "/inventario" in uri: return "inventario"
    if "/pedidos" in uri: return "pedidos"
    if "/auth" in uri: return "autenticacion"
    return "unknown"
    
# aplicamos los cambios
df["uri_servicio"] = df["http_uri"].apply(uri_a_servicio_destino)

# eliminamos las columnas que ya no sirven
cdf = df.drop(columns=["http_uri"])
print(cdf["uri_servicio"].value_counts())
print(len(cdf))
# Out:
# uri_servicio
# unknown          2279
# inventario       1768
# pedidos          1180
# autenticacion      38
# Name: count, dtype: int64
# 5265

# %% [markdown]
# ## Juntamos los logs del mismo servidor cuyo traceID sea igual

# %%
cdf.dtypes
# Out:
# @timestamp           str
# service              str
# level                str
# event_type           str
# http_method          str
# http_status      float64
# duration_ms      float64
# error_type           str
# error_message        str
# error_origin         str
# traceId              str
# uri_servicio         str
# dtype: object

# %%
# Contamos los logs que genero una misma peticion (conocemos que si son 2 suele ser fallo, puede ser una buena medida)
cdf['log_count'] = cdf.groupby(['traceId', 'service'])['traceId'].transform('count')
cdf['log_count'].value_counts()
# Out:
# log_count
# 2    2952
# 1    2313
# Name: count, dtype: int64

# %%
# 1. Asegurarnos de que el dataframe esté ordenado por tiempo
cdf = cdf.sort_values(by=['@timestamp'])

# 2. PROPAGAR EL TRACEID: 
# Agrupamos por tiempo exacto y servicio, y propagamos el traceId hacia atrás (bfill) y hacia adelante (ffill)
# Así, la fila que tiene NaN adoptará el traceId '6a4bac01...' de su fila hermana.
cdf['traceId'] = cdf.groupby(['@timestamp', 'service'])['traceId'].transform(lambda x: x.bfill().ffill())

# Opcional pero recomendado: si queda algún log de sistema puro que no pertenece a ninguna 
# petición (sigue teniendo traceId = NaN), lo filtramos para no meter ruido al modelo.
cdf = cdf.dropna(subset=['traceId'])

# 3. EL DICCIONARIO DE AGREGACIÓN (El que ya teníamos)
agregaciones = {
    '@timestamp': 'min',  
    'level': lambda x: ', '.join(x.dropna().astype(str).unique()),
    'event_type': lambda x: ', '.join(x.dropna().astype(str).unique()),
    'http_method': 'first',
    'http_status': lambda x: ', '.join(x.dropna().astype(str).unique()),
    'duration_ms': 'sum', 
    'error_type': lambda x: ' | '.join(x.dropna().astype(str).unique()),
    'error_message': lambda x: ' | '.join(x.dropna().astype(str).unique()),
    'error_origin': lambda x: ' | '.join(x.dropna().astype(str).unique()),
    'uri_servicio': 'first',
    'log_count':'max'
}

# 4. AGRUPACIÓN FINAL
df_clear = cdf.groupby(['traceId', 'service']).agg(agregaciones).reset_index()

# %%
# arreglamos que ahora haya varios level en uno mismo
def max_level(comb_level):
    level = str(comb_level).upper()
    if 'ERROR' in level:
        return 'ERROR'
    elif 'WARN' in level:
        return 'WARN'
    else:
        return 'INFO'

df_clear['level'] = df_clear['level'].apply(max_level)

# %%
print(f"Tama total del dataset: {len(df_clear)} \n")
print(" ====== COMPROBACION DE DATOS DE ERROR ======")
print("===== LOG_COUNT STATS ===== ")
print(df_clear['log_count'].value_counts())
df_clear[df_clear["http_status"].str.contains('500', na=False)].head()
# Out:
# Tama total del dataset: 3789
#
#  ====== COMPROBACION DE DATOS DE ERROR ======
# ===== LOG_COUNT STATS =====
# log_count
# 1    2313
# 2    1476
# Name: count, dtype: int64
#                              traceId         service  \
# 11  6a476d2cfd455571782d708e1a6d9968     api-pedidos
# 16  6a476d3147869f889d92defc1f2c96fe  api-inventario
# 19  6a476d3242caf70754e9311c31d05f11  api-inventario
# 20  6a476d328b5403ed9dcd89454f2cfbc4  api-inventario
# 21  6a476d328b5403ed9dcd89454f2cfbc4     api-pedidos
#
#                   @timestamp  level                     event_type  \
# 11  2026-07-03T08:05:05.839Z  ERROR  UNHANDLED_ERROR, SERVER_ERROR
# 16  2026-07-03T08:05:35.848Z  ERROR  UNHANDLED_ERROR, SERVER_ERROR
# 19  2026-07-03T08:05:36.847Z  ERROR  UNHANDLED_ERROR, SERVER_ERROR
# 20  2026-07-03T08:05:36.710Z  ERROR  UNHANDLED_ERROR, SERVER_ERROR
# 21  2026-07-03T08:05:11.695Z  ERROR  UNHANDLED_ERROR, SERVER_ERROR
#
#    http_method http_status  duration_ms                        error_type  \
# 11        POST       500.0       5038.0           ResourceAccessException
# 16         GET       500.0      30060.0  CannotCreateTransactionException
# 19         GET       500.0      30015.0  CannotCreateTransactionException
# 20        POST       500.0      30023.0  CannotCreateTransactionException
# 21        POST       500.0       5017.0           ResourceAccessException
#
#                                         error_message  \
# 11  I/O error on POST request for 'http://api-inve...
# 16   Could not open JPA EntityManager for transaction
# 19   Could not open JPA EntityManager for transaction
# 20   Could not open JPA EntityManager for transaction
# 21  I/O error on POST request for 'http://api-inve...
#
#                                          error_origin uri_servicio  log_count
# 11  PedidoService.retirarStockeDeInventario(Pedido...      unknown          2
# 16                                                         unknown          2
# 19                                                         unknown          2
# 20                                                         unknown          2
# 21  PedidoService.retirarStockeDeInventario(Pedido...      unknown          2

# %% [markdown]
# # Pipelines

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# event_type, service, http_metod, http_status -> one hot encoding
categorical_scaler = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='constant', fill_value='NONE')),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# duration_ms -> Standar scaler
num_scaler = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# level -> OrdinalEncodera
level_pipeline = Pipeline(steps=[
    ('inputer', SimpleImputer(strategy='constant',fill_value='INFO')),
    ('ordinal', OrdinalEncoder(categories=[["INFO", "WARN", "ERROR"]]))
])

# NPL (TFIDF) -> error_type, error_origin
tf_pipeline = Pipeline(steps=[
    # ('inputer', SimpleImputer(strategy='constant', fill_value='NONE')),
    ('vectorizador', TfidfVectorizer())
])

# Clase para descpomponer timestamp
class TimestampDescomponedor(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self  
    
    def transform(self, X):
        # Convierte a Series independientemente de si llega como DataFrame, array o Series
        if hasattr(X, 'iloc'):
            # Es un DataFrame — coge la primera columna
            serie = pd.to_datetime(X.iloc[:, 0])
        else:
            # Es un array numpy
            serie = pd.to_datetime(pd.Series(X.ravel()))
        
        resultado = pd.DataFrame({
            "hour_of_day":    serie.dt.hour,
            "day_of_week":    serie.dt.dayofweek,
            "minute_of_hour": serie.dt.minute
        })
        
        return resultado.values
        
    def get_feature_names_out(self, input_features=None):
        return np.array(["ts__hour_of_day", "ts__day_of_week", "ts__minute_of_hour"])

timestamp_pipeline = Pipeline(steps=[
    ("descomponedor", TimestampDescomponedor()),
    ("scaler", StandardScaler())
])

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(transformers=[
    ("cat", categorical_scaler, ["event_type", "service", "http_method", "uri_servicio", "http_status"]),
    ("num", num_scaler, ["duration_ms", "log_count"]),
    ("ts", timestamp_pipeline, ["@timestamp"]),
    ("ord", level_pipeline, ["level"]),
    ('text_processor', tf_pipeline, "texto_completo")
])

# %% [markdown]
# # ISOLATION FOREST + TF-IDF (ya aplicado)
# ### GridSearch, Train test split, train

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
import re

# para evitar data leakage, calculamos sobre los dataframes separados la variable de supervisado
def etiquetado(fila):
    if '500' in str(fila['http_status']) or 'ERROR' in str(fila['level']):
        return -1
    else:
        return 1
        
df_clear['es_anomalia'] = df_clear.apply(etiquetado, axis=1)

# quitamos los valores nulos por X´s para que el TF-IDF no tenga problemas
df_clear['error_message'] = df_clear['error_message'].fillna('X')
df_clear['error_type'] = df_clear['error_type'].fillna('X')

# dejamos el texto entero para que lo procese nlp junto
def limpiar_texto(texto):
    if texto == "X" or pd.isna(texto):
        return ""
    
    texto = re.sub(r":\d+", "", texto)
    texto = re.sub(r"[^a-zA-Z\s]", " ", texto)
    return texto.lower().strip()

df_clear["texto_completo"] = (
    df_clear["error_type"].apply(limpiar_texto) + " " +
    df_clear["error_message"].apply(limpiar_texto) + " " +
    df_clear["error_origin"].apply(limpiar_texto)
)

df_clear['texto_completo'] = df_clear['error_type'] + " " + df_clear['error_message']
df_clear = df_clear.drop(columns=['error_type', 'error_message'])

print(df_clear['es_anomalia'].value_counts())
# Out:
# es_anomalia
# -1    2279
#  1    1510
# Name: count, dtype: int64

# %%
df_clear.head()
# Out:
#                             traceId            service  \
# 0  6a476cca227cf2c2a7778eea6814c767  api-autenticacion
# 1  6a476ccf073988540242f264230c10a8     api-inventario
# 2  6a476cd501fdf3e29f19f31f7e7dca68     api-inventario
# 3  6a476cd735ddf16a117971907acb4d4e     api-inventario
# 4  6a476cd735ddf16a117971907acb4d4e        api-pedidos
#
#                  @timestamp level    event_type http_method http_status  \
# 0  2026-07-03T08:03:23.032Z  INFO  HTTP_REQUEST        POST       201.0
# 1  2026-07-03T08:03:27.935Z  INFO  HTTP_REQUEST        POST       200.0
# 2  2026-07-03T08:03:33.981Z  INFO  HTTP_REQUEST         GET       200.0
# 3  2026-07-03T08:03:36.098Z  INFO  HTTP_REQUEST        POST       200.0
# 4  2026-07-03T08:03:36.202Z  INFO  HTTP_REQUEST        POST       200.0
#
#    duration_ms error_origin   uri_servicio  log_count  es_anomalia  \
# 0        363.0               autenticacion          1            1
# 1        158.0                  inventario          1            1
# 2         92.0                  inventario          1            1
# 3         40.0                  inventario          1            1
# 4        297.0                     pedidos          1            1
#
#   texto_completo
# 0
# 1
# 2
# 3
# 4

# %%
X = df_clear.drop(columns=['es_anomalia'])
y = df_clear['es_anomalia']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# %% [markdown]
# ### Make scoring

# %%
from sklearn.metrics import make_scorer, f1_score

anomalia_scorer=make_scorer(f1_score, pos_label=-1)

# %% [markdown]
# ### Grid y fit

# %%
from sklearn.ensemble import IsolationForest
isolation_estimator = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', IsolationForest(random_state=42))
])

param_grid = {
    # Ajustes para el TF-IDF
    'preprocessor__text_processor__vectorizador__max_features': [100, 300, 500, None],
    'preprocessor__text_processor__vectorizador__ngram_range': [(1, 1), (1, 2)], # Probar palabras sueltas vs pares de palabras
    'preprocessor__text_processor__vectorizador__max_df': [0.7, 0.9],
    'preprocessor__text_processor__vectorizador__min_df': [1, 2],
    
    # Ajustes para el Isolation Forest
    'model__n_estimators': [100, 200],
    'model__contamination': [0.01, 0.05, 'auto']
}

isolation_search = GridSearchCV(
    estimator=isolation_estimator,
    param_grid=param_grid,
    cv=5,
    n_jobs=1,
    # verbose=2,
    scoring=anomalia_scorer
)

# %%
isolation_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='NONE',
#                                                                                                         strategy='constant')),
#                                                                                          ('one_hot',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          ['event_type',
#                                                                           'service',
#                                                                           'http_method',
#                                                                           'uri_servicio',
#                                                                           'http_status']),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('imp...
#                          'model__n_estimators': [100, 200],
#                          'preprocessor__text_processor__vectorizador__max_df': [0.7,
#                                                                                 0.9],
#                          'preprocessor__text_processor__vectorizador__max_features': [100,
#                                                                                       300,
#                                                                                       500,
#                                                                                       None],
#                          'preprocessor__text_processor__vectorizador__min_df': [1,
#                                                                                 2],
#                          'preprocessor__text_processor__vectorizador__ngram_range': [(1,
#                                                                                       1),
#                                                                                      (1,
#                                                                                       2)]},
#              scoring=make_scorer(f1_score, response_method='predict', pos_label=-1))

# %%
print(f"Mejores parámetros encontrados: {isolation_search.best_params_}")
print(f"Mejor F1-Score: {isolation_search.best_score_}")
# Out:
# Mejores parámetros encontrados: {'model__contamination': 'auto', 'model__n_estimators': 200, 'preprocessor__text_processor__vectorizador__max_df': 0.7, 'preprocessor__text_processor__vectorizador__max_features': 100, 'preprocessor__text_processor__vectorizador__min_df': 2, 'preprocessor__text_processor__vectorizador__ngram_range': (1, 2)}
# Mejor F1-Score: 0.8449024834723439

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

isolation_model = isolation_search.best_estimator_

y_pred = isolation_model.predict(X_test)

cf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
sns.heatmap(cf_matrix, annot=True, cmap='crest', fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# # Data Engineering: Creacion de nuevas variables y cambios en el dataset
# ### Banderas binarias para el estado HTTP
# - Creamos bandernas binarias para que el modelo pueda apoyarse en ellas directamente a la hora de detectar un error

# %%
df_clear.columns
# Out:
# Index(['traceId', 'service', '@timestamp', 'level', 'event_type',
#        'http_method', 'http_status', 'duration_ms', 'error_origin',
#        'uri_servicio', 'log_count', 'es_anomalia', 'texto_completo'],
#       dtype='str')

# %%
df_clear['tiene_error_5xx'] = df_clear['http_status'].astype(str).str.contains(r'5\d{2}').astype(int)
df_clear = df_clear.drop(columns=['http_status'])
df_clear.columns
# Out:
# Index(['traceId', 'service', '@timestamp', 'level', 'event_type',
#        'http_method', 'duration_ms', 'error_origin', 'uri_servicio',
#        'log_count', 'es_anomalia', 'texto_completo', 'tiene_error_5xx'],
#       dtype='str')

# %%
param_grid = {
    # Ajustes para el TF-IDF
    'preprocessor__text_processor__vectorizador__max_features': [10, 30, 50],
    'preprocessor__text_processor__vectorizador__ngram_range': [(1, 1), (1, 2)], # Probar palabras sueltas vs pares de palabras
    'preprocessor__text_processor__vectorizador__max_df': [0.7, 0.9],
    'preprocessor__text_processor__vectorizador__min_df': [1, 2],
    
    # Ajustes para el Isolation Forest
    'model__n_estimators': [100, 200],
    'model__contamination': [0.01, 0.05, 'auto']
}

preprocessor = ColumnTransformer(transformers=[
    ("cat", categorical_scaler, ["event_type", "service", "http_method", "uri_servicio"]),
    ("num", num_scaler, ["duration_ms", "tiene_error_5xx", "log_count"]),
    ("ts", timestamp_pipeline, ["@timestamp"]),
    ("ord", level_pipeline, ["level"]),
    ('text_processor', tf_pipeline, "texto_completo")
])

# %%
# VOLVEMOS A GENERAR EL DF DE ENTRENAMIENTO

X = df_clear.drop(columns=['es_anomalia'])
y = df_clear['es_anomalia']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# ENTRENAMOS DE NUEVO
isolation_estimator = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', IsolationForest(random_state=42))
])

isolation_search = GridSearchCV(
    estimator=isolation_estimator,
    param_grid=param_grid,
    cv=5,
    n_jobs=1,
    # verbose=2,
    scoring=anomalia_scorer
)

isolation_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='NONE',
#                                                                                                         strategy='constant')),
#                                                                                          ('one_hot',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          ['event_type',
#                                                                           'service',
#                                                                           'http_method',
#                                                                           'uri_servicio']),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleIm...
#                          'model__n_estimators': [100, 200],
#                          'preprocessor__text_processor__vectorizador__max_df': [0.7,
#                                                                                 0.9],
#                          'preprocessor__text_processor__vectorizador__max_features': [10,
#                                                                                       30,
#                                                                                       50],
#                          'preprocessor__text_processor__vectorizador__min_df': [1,
#                                                                                 2],
#                          'preprocessor__text_processor__vectorizador__ngram_range': [(1,
#                                                                                       1),
#                                                                                      (1,
#                                                                                       2)]},
#              scoring=make_scorer(f1_score, response_method='predict', pos_label=-1))

# %%
print(f"Mejores parámetros encontrados: {isolation_search.best_params_}")
print(f"Mejor F1-Score: {isolation_search.best_score_}")
# Out:
# Mejores parámetros encontrados: {'model__contamination': 'auto', 'model__n_estimators': 200, 'preprocessor__text_processor__vectorizador__max_df': 0.7, 'preprocessor__text_processor__vectorizador__max_features': 50, 'preprocessor__text_processor__vectorizador__min_df': 1, 'preprocessor__text_processor__vectorizador__ngram_range': (1, 1)}
# Mejor F1-Score: 0.8313563016235344

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

isolation_model = isolation_search.best_estimator_

y_pred = isolation_model.predict(X_test)

cf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
sns.heatmap(cf_matrix, annot=True, cmap='crest', fmt='d')
# Out:
# <Axes: >

# %%
# indagamos sobre la importancia que estan tomando las variables
import shap
import matplotlib.pyplot as plt

# cogemos el preprocesador y el modelo 
preproc_model=isolation_model.named_steps['preprocessor']
model_if=isolation_model.named_steps['model']

# cogemos el nombre de las colum y transofrmamos el test
nombre_features=preproc_model.get_feature_names_out()
X_test_transformado= preproc_model.transform(X_test)

explainer=shap.TreeExplainer(model_if)
shap_values=explainer.shap_values(X_test_transformado)
plt.figure(figsize=(10,6))
shap.summary_plot(shap_values, X_test_transformado, feature_names=nombre_features, plot_type="bar")

# %% [markdown]
# Resulta que el modelo está fijandose en variables que no debería. Por lo tanto, para eliminar atajos, quitamos lo siguiente:
# - http_method: Esta aprendiendo que todos los POST son los que generan fallos
# - timestamp: Los datset han sido generados basicamente a las mismas horas, por lo tanto no es un ejemplo real
# - service: Esto conlleva que el modelo acabe pensando que uno de los microservicios es defectuoso y que, vienndo de uno en concreto, resulte mas problable fallar.

# %%
print("Log count values")
print(df_clear['log_count'].value_counts())
df_clear.head()
# Out:
# Log count values
# log_count
# 1    2313
# 2    1476
# Name: count, dtype: int64
#                             traceId level    event_type http_method  \
# 0  6a476cca227cf2c2a7778eea6814c767  INFO  HTTP_REQUEST        POST
# 1  6a476ccf073988540242f264230c10a8  INFO  HTTP_REQUEST        POST
# 2  6a476cd501fdf3e29f19f31f7e7dca68  INFO  HTTP_REQUEST         GET
# 3  6a476cd735ddf16a117971907acb4d4e  INFO  HTTP_REQUEST        POST
# 4  6a476cd735ddf16a117971907acb4d4e  INFO  HTTP_REQUEST        POST
#
#    duration_ms error_origin  log_count  es_anomalia texto_completo  \
# 0        363.0                       1            1
# 1        158.0                       1            1
# 2         92.0                       1            1
# 3         40.0                       1            1
# 4        297.0                       1            1
#
#    tiene_error_5xx  duracion_relativa level_final  is_cascada
# 0                0           2.719637        INFO           0
# 1                0           0.017159        INFO           0
# 2                0           0.009991        INFO           0
# 3                0           0.004344        INFO           0
# 4                0           0.061122        INFO           0

# %% [markdown]
# #### Features Nuevas
# - Incluimos una feature que indica cuando se desvia la latencia del baseline normal
# - Incluimos is_cascada, una variable binaria que se encarga de marcar aquellos errores que han sido en cascada
# - Mejoramos error_type y error_message quitando caracteres especiales y numeros que aportan impreciosion al NLP

# %%
baseline = df_clear[df_clear["es_anomalia"] == 1].groupby("service")["duration_ms"].mean()

df_clear["duracion_relativa"] = df_clear.apply(
    lambda row: row["duration_ms"] / baseline.get(row["service"], 1),
    axis=1
)

# Marcamos las cascadas
def marcar_cascada(df):
    # Primero aplica max_level para tener el level final de cada fila
    df['level_final'] = df['level'].apply(max_level)
    
    # traceIds que tienen ERROR en al menos dos servicios distintos
    errores_por_trace = (
        df[df['level_final'] == 'ERROR']
        .groupby('traceId')['service']
        .nunique()
    )
    traces_cascada = errores_por_trace[errores_por_trace > 1].index
    df['is_cascada'] = df['traceId'].isin(traces_cascada).astype(int)
    
    return df

df_clear = marcar_cascada(df_clear)

# %% [markdown]
# - Como esta utilizando las horas para detectar anomalias y esta haciendo "trampa" con eso, retiramos el timestamp.
# - Tambien retiramos uri_servicio y service, ya que esta detectando anomalias por los servicios, tomando alguno como m'as anomalos que otros

# %%
df_clear = df_clear.drop(columns=["@timestamp", "service", "uri_servicio"])

# %%
# cambiamos sStandardScaler por Robust
from sklearn.preprocessing import RobustScaler

num_scaler = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

param_grid = {
    # Ajustes para el TF-IDF
    'preprocessor__text_processor__vectorizador__max_features': [10, 30, 50, 100],
    'preprocessor__text_processor__vectorizador__ngram_range': [(1, 1), (1, 2)], # Probar palabras sueltas vs pares de palabras
    'preprocessor__text_processor__vectorizador__max_df': [0.7, 0.9],
    'preprocessor__text_processor__vectorizador__min_df': [1, 2],
    
    # Ajustes para el Isolation Forest
    'model__n_estimators': [100, 200],
    'model__contamination': [0.05, 0.10, 0.15, 0.20, 'auto']
}

preprocessor = ColumnTransformer(transformers=[
    ("cat", categorical_scaler, ["event_type", "http_method"]),
    ("num", num_scaler, ["duration_ms", "duracion_relativa", "log_count"]),
    ("bin", "passthrough", ["tiene_error_5xx", "is_cascada"]),
    # ("ts", timestamp_pipeline, ["@timestamp"]),
    ("ord", level_pipeline, ["level"]),
    ('text_processor', tf_pipeline, "texto_completo"),
    ('text_processor_origin', tf_pipeline, "error_origin")
])

# %%
# VOLVEMOS A GENERAR EL DF DE ENTRENAMIENTO

X = df_clear.drop(columns=['es_anomalia'])
y = df_clear['es_anomalia']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# ENTRENAMOS DE NUEVO
isolation_estimator = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', IsolationForest(random_state=42))
])

isolation_search = GridSearchCV(
    estimator=isolation_estimator,
    param_grid=param_grid,
    cv=5,
    n_jobs=1,
    # verbose=2,
    scoring=anomalia_scorer
)

isolation_search.fit(X_train, y_train)
isolation_search.best_params_
# Out:
# {'model__contamination': 'auto',
#  'model__n_estimators': 200,
#  'preprocessor__text_processor__vectorizador__max_df': 0.7,
#  'preprocessor__text_processor__vectorizador__max_features': 30,
#  'preprocessor__text_processor__vectorizador__min_df': 1,
#  'preprocessor__text_processor__vectorizador__ngram_range': (1, 2)}

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

isolation_model = isolation_search.best_estimator_

y_pred = isolation_model.predict(X_test)

cf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
sns.heatmap(cf_matrix, annot=True, cmap='crest', fmt='d')
# Out:
# <Axes: >

# %%
print(f'Mejor f1-score: {isolation_search.best_score_}')
# Out:
# Mejor f1-score: 0.8449378049632402

# %%
# cogemos el preprocesador y el modelo 
preproc_model=isolation_model.named_steps['preprocessor']
model_if=isolation_model.named_steps['model']

# cogemos el nombre de las colum y transofrmamos el test
nombre_features=preproc_model.get_feature_names_out()
X_test_transformado= preproc_model.transform(X_test)

explainer=shap.TreeExplainer(model_if)
shap_values=explainer.shap_values(X_test_transformado)
plt.figure(figsize=(10,6))
shap.summary_plot(shap_values, X_test_transformado, feature_names=nombre_features, plot_type="bar")

# %%
X_test.head()
# Out:
#                                traceId level    event_type http_method  \
# 322   6a476ed3738e16bf0af3098096c28764  INFO  HTTP_REQUEST         GET
# 985   6a477185039eb92d63a8d8c6fcccbdb2  INFO  HTTP_REQUEST         GET
# 3447  6a4bad55c16c99e1bbdbf2a0e7a3600d  INFO  HTTP_REQUEST         GET
# 1159  6a47722ad54677efce3400210ee89783  INFO  HTTP_REQUEST        POST
# 1886  6a4775758c2c74a1e5aeb624f11b9ab8  INFO  HTTP_REQUEST         GET
#
#       duration_ms error_origin  log_count texto_completo  tiene_error_5xx  \
# 322       11573.0                       1                               0
# 985       24713.0                       1                               0
# 3447      23567.0                       1                               0
# 1159       4824.0                       1                               0
# 1886      16127.0                       1                               0
#
#       duracion_relativa level_final  is_cascada
# 322            1.256838        INFO           0
# 985            2.683854        INFO           0
# 3447           2.559398        INFO           0
# 1159           0.523891        INFO           0
# 1886           1.751407        INFO           0

# %%
cf_matrix
